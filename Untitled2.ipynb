# %%
import pandas as pd
import requests

url = "https://coinstats.app/"

r = requests.get(url)
df_list = pd.read_html(r.text) 
df = df_list[0]
df.head(20)
# Out:
#      #                     Name 24h Change       Price  Price in BTC  \
# 0    1            Bitcoin • BTC     -0.94%  $36,578.72      1.000000
# 1    2           Ethereum • ETH      2.26%   $2,622.41      0.071687
# 2    3            Tether • USDT     -0.01%          $1      0.000027
# 3    4            Cardano • ADA      3.25%       $1.72      0.000047
# 4    5       Binance Coin • BNB      1.45%      $353.4      0.009661
# 5    6                XRP • XRP      1.89%       $1.03      0.000028
# 6    7          Dogecoin • DOGE      4.00%   $0.328674      0.000009
# 7    8          USD Coin • USDC      0.23%          $1      0.000027
# 8    9           Polkadot • DOT      4.25%      $22.63      0.000619
# 9   10            Uniswap • UNI      2.72%      $27.46      0.000751
# 10  11  Internet Computer • ICP     -2.27%     $110.65      0.003025
# 11  12         Chainlink • LINK      4.20%      $30.38      0.000831
# 12  13       Bitcoin Cash • BCH     -0.53%     $688.33      0.018816
# ...
