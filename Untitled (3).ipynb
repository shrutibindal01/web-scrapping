# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.7/site-packages (2.25.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests) (1.26.3)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests) (4.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install html5lib
# Out:
# Collecting html5lib
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 3.9 MB/s eta 0:00:01
# Requirement already satisfied: webencodings in /srv/conda/envs/notebook/lib/python3.7/site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from html5lib) (1.15.0)
# Installing collected packages: html5lib
# Successfully installed html5lib-1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-4.6.3-cp37-cp37m-manylinux2014_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 4.2 MB/s eta 0:00:01     |█████▉                          | 1.1 MB 4.2 MB/s eta 0:00:02                  | 1.8 MB 4.2 MB/s eta 0:00:02
# Installing collected packages: lxml
# Successfully installed lxml-4.6.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 3.1 MB/s eta 0:00:01
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.2.1-py3-none-any.whl (33 kB)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1273 sha256=6f652975cef7ca39b39c8f30ecc3ad08ce9244499c6473eef00517487ed9fcfe
#   Stored in directory: /home/jovyan/.cache/pip/wheels/0a/9e/ba/20e5bbc1afef3a491f0b3bb74d508f99403aabe76eda2167ca
# Successfully built bs4
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.9.3 bs4-0.0.1 soupsieve-2.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import csv
   
URL = "https://coinstats.app/"
r = requests.get(URL)
   
soup = BeautifulSoup(r.content, 'html5lib')
table = soup.find("table", { "class" : "lineItemsTable" })
for row in table.findAll("tr"):
    cells = row.findAll("td")
    print cells
# Out:
#   File "<ipython-input-6-896639f13e78>", line 12
#     print cells
#               ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(cells)?

# %%
pip install cells
# Out:
# ERROR: Could not find a version that satisfies the requirement cells
# ERROR: No matching distribution found for cells
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import csv
   
URL = "https://coinstats.app/"
r = requests.get(URL)
   
soup = BeautifulSoup(r.content, 'html5lib')
table = soup.find("table", { "class" : "lineItemsTable" })
for row in table.findAll("tr"):
    cells = row.findAll("td")
    print cells
# Out:
#   File "<ipython-input-8-896639f13e78>", line 12
#     print cells
#               ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(cells)?

# %%
type(print)
# Out:
# builtin_function_or_method

# %%
data = []
table = soup.find('table', attrs={'class':'lineItemsTable'})
table_body = table.find('tbody')

rows = table_body.find_all('tr')
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append([ele for ele in cols if ele]) # Get rid of empty values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-eb50e1f07269> in <module>
#       1 data = []
#       2 table = soup.find('table', attrs={'class':'lineItemsTable'})
# ----> 3 table_body = table.find('tbody')
#       4
#       5 rows = table_body.find_all('tr')
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
import pandas as pd
import requests

url = "https://coinstats.app/"

r = requests.get(url)
df_list = pd.read_html(r.text) # this parses all the tables in webpages to a list
df = df_list[0]
df.head()
# Out:
#    #                Name 24h Change      Price  Price in BTC Market Cap  \
# 0  1       Bitcoin • BTC     -0.99%  $36,298.9      1.000000    $679.6B
# 1  2      Ethereum • ETH      1.91%  $2,583.37      0.071214    $300.0B
# 2  3       Tether • USDT      0.00%         $1      0.000028     $62.0B
# 3  4       Cardano • ADA      4.13%      $1.71      0.000047     $54.7B
# 4  5  Binance Coin • BNB      3.03%    $350.01      0.009648     $54.1B
#
#   Volume 24h  Price Graph (7D)  Unnamed: 8
# 0      $2.6T               NaN         NaN
# 1      $1.0T               NaN         NaN
# 2    $180.4B               NaN         NaN
# 3      $4.7B               NaN         NaN
# 4     $32.1B               NaN         NaN
